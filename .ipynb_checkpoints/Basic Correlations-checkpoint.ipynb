# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy import stats
pd.options.display.max_columns = None

# %% [markdown]
# ## Various Correlations
# #### box office with rating

# %%
wikidata = pd.read_json('movies/data/wikidata-movies2.json.gz', orient='records', lines=True)
tomato = pd.read_json('movies/data/rotten-tomatoes.json.gz', orient='records', lines=True)
r = pd.read_json('movies/data/omdb-data.json.gz', orient='records', lines=True)

# %%
wiki_tomato = wikidata.merge(tomato, on='imdb_id', how="inner")

# %%
wiki_tomato = wiki_tomato[pd.notnull(wiki_tomato['nbox'])]
wiki_tomato = wiki_tomato[pd.notnull(wiki_tomato['critic_percent'])]
wiki_tomato = wiki_tomato[pd.notnull(wiki_tomato['audience_percent'])]

# %%
def millions(x, pos):
    return '%1.1fM' % (x * 1e-6)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
y_labels = ax.get_yticks()
ax.yaxis.set_major_formatter(ticker.FormatStrFormatter)
ax.scatter(wiki_tomato['audience_percent'], wiki_tomato['nbox'], marker='o', label='audience')
ax.scatter(wiki_tomato['critic_percent'], wiki_tomato['nbox'], marker='^', label='critic')
plt.legend(loc='upper left')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-57-8c5348219a93> in <module>()
#       6 ax.scatter(wiki_tomato['critic_percent'], wiki_tomato['nbox'], marker='^', label='critic')
#       7 plt.legend(loc='upper left')
# ----> 8 plt.tight_layout()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1364     """
#    1365     fig = gcf()
# -> 1366     fig.tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1367
#    1368
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2273         kwargs = get_tight_layout_figure(
#    2274             self, self.axes, subplotspec_list, renderer,
# ...
