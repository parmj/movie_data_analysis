# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# #### Which genres are most successful (profitable)?

# %%
df = pd.read_json('movies/data/wikidata-movies.json.gz', orient='records', lines=True)
df2 = pd.read_json('movies/data/wikidata-movies2.json.gz', orient='records', lines=True)
genres = pd.read_json('movies/data/genres.json.gz', orient='records', lines=True)

# %%
df = df[pd.notnull(df['made_profit'])]

# %%
#df['genre'] = df['genre'].str[0]
#genres.columns = ['genre_label', 'genre']

# %%
#merged = pd.merge(df, genres, on="genre")

# %%
df_stack = df['genre'].apply(pd.Series).stack().reset_index(level=1, drop=True).to_frame()
df_stack.columns = ['wikidata_id']

# %%
df_genre = df_stack.reset_index().merge(genres, how="left", on="wikidata_id").set_index('index')

# %%
df_genre = pd.merge(df_genre, df, left_index=True, right_index=True).reset_index()

# %%
genres['profit'] = genres['genre_label'].apply(lambda x: df_genre[(df_genre['genre_label'] == x) & (df_genre['made_profit'] == True)].shape[0])
genres['noprofit'] = genres['genre_label'].apply(lambda x: df_genre[(df_genre['genre_label'] == x) & (df_genre['made_profit'] == False)].shape[0])

# %%
df_genre[(df_genre['country_of_origin'] == 'Q29') & (df_genre['made_profit'] == True)].shape[0]
# Out:
# 7

# %%
df_genre = genres.sort_values(by='profit', ascending=False)
df_genre = df_genre[(df_genre['profit'] != 0) & (df_genre['noprofit'] != 0)]

# %%
# profit_percent = profit/total
df_genre['profit_percent'] = df_genre['profit'] / (df_genre['profit'] + df_genre['noprofit'])

# %%
df_genre.sort_values(by='profit', ascending=False)
# Out:
#                    genre_label wikidata_id  profit  noprofit  profit_percent
# 2586                drama film     Q130232     226        46        0.830882
# 4664               action film     Q188473     198        41        0.828452
# 4632               comedy film     Q157443     162        27        0.857143
# 2782      science fiction film     Q471839     130        12        0.915493
# 112   film based on literature   Q52162262     119        16        0.881481
# 2601              fantasy film     Q157394     109        16        0.872000
# 1042             thriller film    Q2484376     108        14        0.885246
# 5248            adventure film     Q319221     104        15        0.873950
# 2653               horror film     Q200092      70         8        0.897436
# 4915                crime film     Q959790      60        11        0.845070
# 1713              musical film     Q842256      54         9        0.857143
# 3784           romantic comedy     Q860626      53         6        0.898305
# 3323              comedy-drama     Q859369      49         2        0.960784
# 4937              romance film    Q1054574      44         5        0.897959
# 3713         biographical film     Q645928      41        11        0.788462
# 2216                  war film     Q369747      40         5        0.888889
# 1162              mystery film    Q1200678      37         4        0.902439
# 3720                buddy film     Q663106      32         4        0.888889
# 118   speculative fiction film    Q2973181      32         3        0.914286
# 3666         LGBT-related film   Q20442589      30         2        0.937500
# 1872            superhero film    Q1535153      30         1        0.967742
# 4438           children's film    Q2143665      29         8        0.783784
# 860             dystopian film   Q20443008      28         6        0.823529
# 2948                 teen film    Q1146335      27         6        0.818182
# 2109                  thriller     Q182015      26         4        0.866667
# 1252                 melodrama    Q1919632      25         4        0.862069
# 5153                 melodrama     Q191489      25         4        0.862069
# 3595       coming-of-age story    Q2975633      22         3        0.880000
# 3886               family film    Q1361932      20         6        0.769231
# 15                       drama   Q39892385      19         9        0.678571
# ...                        ...         ...     ...       ...             ...
# 5092          documentary film      Q93204       7         1        0.875000
# 331        speculative fiction    Q5967378       6         2        0.750000
# 2036                    comedy      Q40831       6         1        0.857143
# 3547              vampire film    Q2137852       6         1        0.857143
# 2475       fictional crossover   Q21192427       6         1        0.857143
# 1462              black comedy      Q53094       5         1        0.833333
# 3319              slasher film     Q853630       5         1        0.833333
# 1645               parody film     Q622548       5         1        0.833333
# 4210               zombie film    Q3072049       5         2        0.714286
# 1978                   musical       Q2743       4         1        0.800000
# 2836                 epic film     Q652256       4         1        0.800000
# 4619                   fantasy     Q132311       4         3        0.571429
# 920                    fantasy    Q1356411       4         3        0.571429
# 3420               sports film    Q1339864       4         1        0.800000
# 3585        action comedy film    Q2678111       3         1        0.750000
# 323          female buddy film    Q5442753       3         1        0.750000
# 5215               silent film     Q226730       3         1        0.750000
# 3896         peplum film genre    Q1433443       2         2        0.500000
# 2210           science fiction     Q336059       2         2        0.500000
# 2019           science fiction      Q24925       2         2        0.500000
# 2657             animated film     Q202866       2         1        0.666667
# 4798             costume drama     Q542475       2         1        0.666667
# 5099                    satire     Q128758       2         1        0.666667
# 724          black comedy film    Q5778924       2         1        0.666667
# 3006                 adventure    Q1436734       2         1        0.666667
# 2116                 film noir     Q185867       1         1        0.500000
# 5132               time travel     Q182154       1         1        0.500000
# 5164  post-apocalyptic fiction     Q197949       1         1        0.500000
# 3051         crime-comedy film    Q1788980       1         1        0.500000
# 1235             zombie comedy    Q1747837       1         1        0.500000
#
# [81 rows x 5 columns]

# %%
contingency = np.vstack([df_genre['profit'], df_genre['noprofit']])

# %%
chi2, p, dof, expected = stats.chi2_contingency(contingency)

# %%
# p value of chi test on genre, profit, noprofit
p
# Out:
# 0.008127575360670712

# %%
#draw plt
fig, ax = plt.subplots(figsize=(10, 5))
df_genre = df_genre.sort_values(by='profit_percent', ascending=False)
ax.bar( df_genre['genre_label'][:10], df_genre['profit_percent'][:10])
plt.xlabel = 'Percentage of Films that were Profitable'
xticks = ax.get_xticks()
ax.set_xticklabels(df_genre['genre_label'][:10], rotation=60)
ax.set(xlabel='Genre', ylabel='Percentage of Movies that were Profitable')
plt.ylim(ymin=0.9)
#plt.yscale("log")
plt.tight_layout()
plt.savefig('images/genre-profit.png', dpi=300)
